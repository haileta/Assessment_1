# %%
import requests
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import googlemaps
import json
import beautifulsoup4 # for web scraping

# %% [markdown]
# I tried to use Yelp for a better API but they won't let me open account so i decided to use googlemaps

# %%
API_KEY = "AIzaSyACIEzU1k0NKrDkBVq7pJPBg54T8VQv5NU"
gmaps = googlemaps.Client(key=API_KEY)

food_trucks = []
# search queries for food trucks in Indianapolis
queries = [
    "food trucks in downtown Indianapolis",
    "food trucks in north Indianapolis",
    "food trucks in south Indianapolis",
    "food trucks in west Indianapolis",
    "food trucks in east Indianapolis",
    "food trucks in Broad Ripple, Indianapolis",
    "food trucks in Fountain Square, Indianapolis",
    "food trucks in Mass Ave, Indianapolis",
    "food trucks in IUPUI, Indianapolis",
    "food trucks in near me, Indianapolis",
    "food trucks in Lockerbie Square, Indianapolis",
    "food trucks in Irvington, Indianapolis",
    "food trucks in Beech Grove, Indianapolis",
    "food trucks in Carmel, Indianapolis",
    "food trucks in Castleton, Indianapolis",
]

for query in queries:
    url = f"https://maps.googleapis.com/maps/api/place/findplacefromtext/json?input={query}&inputtype=textquery&fields=formatted_address%2Cname%2Crating&key={API_KEY}"
    response = requests.get(url)
    data = json.loads(response.content)

    for result in data.get("candidates", []):
        food_truck = {}
        name = result.get("name", "N/A")
        
        if name not in {ft["name"] for ft in food_trucks}:
            food_truck["name"] = name
            food_truck["address"] = result.get("formatted_address", "N/A")
            food_truck["rating"] = result.get("rating", "N/A")
            food_trucks.append(food_truck)
df = pd.DataFrame(food_trucks)
df.head()
# Out:
#                             name  \
# 0                   ClusterTruck
# 1      big Jerry Indy food truck
# 2              FELIX TACOS TRUCK
# 3  The Latin Flavor - Food Truck
# 4    ClusterTruck - Broad Ripple
#
#                                              address  rating
# 0  729 N Pennsylvania St, Indianapolis, IN 46204,...     4.8
# 1  8522 Madison Ave, Indianapolis, IN 46227, Unit...     5.0
# 2  3145 W Washington St, Indianapolis, IN 46222, ...     4.5
# 3  9130 E 38th St, Indianapolis, IN 46235, United...     4.1
# 4  2101 E 62nd St, Indianapolis, IN 46220, United...     4.9

# %%
#remove duplicates or handle missing values
df_cleaned = df.drop_duplicates()

# %%
# Export the cleaned data to a CSV file
df_cleaned.to_csv("df_cleaned.csv", index=False)
df_cleaned.shape
# Out:
# (10, 3)

# %%
# to find the highest-rated food trucks:
highest_rated_trucks = df_cleaned.sort_values("rating", ascending=False).head(10)
highest_rated_trucks
# Out:
#                             name  \
# 1      big Jerry Indy food truck
# 6       El Buenavista Food Truck
# 4    ClusterTruck - Broad Ripple
# 9       ClusterTruck - Castleton
# 0                   ClusterTruck
# 7                    Pronto Taco
# 2              FELIX TACOS TRUCK
# 5       Tortas Guicho Food Truck
# 8  Mi Lindo Pénjamo - Food Truck
# 3  The Latin Flavor - Food Truck
#
#                                              address  rating
# 1  8522 Madison Ave, Indianapolis, IN 46227, Unit...     5.0
# 6  5210 English Ave, Indianapolis, IN 46219, Unit...     5.0
# 4  2101 E 62nd St, Indianapolis, IN 46220, United...     4.9
# 9  4737 E 82nd St, Indianapolis, IN 46250, United...     4.9
# 0  729 N Pennsylvania St, Indianapolis, IN 46204,...     4.8
# 7  403 Main St, Beech Grove, IN 46107, United States     4.8
# 2  3145 W Washington St, Indianapolis, IN 46222, ...     4.5
# 5  S. East St and, Fletcher Ave, Indianapolis, IN...     4.5
# ...

# %%
foodie_plan = pd.DataFrame({
    "Day": [1, 1, 1, 2, 2],
    "Time": ["10:00 AM", "12:30 PM", "11:00 AM", "10:30 AM", "1:30 PM"],
    "Location Name": [
        f"Food Truck 1 -> {df_cleaned['name'].iloc[0]}",
        f"Food Truck 2 -> {df_cleaned['name'].iloc[1]}",
        f"Food Truck 3 -> {df_cleaned['name'].iloc[2]}",
        f"Food Truck 4 -> {df_cleaned['name'].iloc[3]}",
        f"Food Truck 5 -> {df_cleaned['name'].iloc[4]}"
    ],
    "Address": [
        f"Address 1 -> {df_cleaned['address'].iloc[0]}",
        f"Address 2 -> {df_cleaned['address'].iloc[1]}",
        f"Address 3 -> {df_cleaned['address'].iloc[2]}",
        f"Address 4 -> {df_cleaned['address'].iloc[3]}",
        f"Address 5 -> {df_cleaned['address'].iloc[4]}"
    ],
    "Transportation Type": ["Walking", "Biking", "Walking", "Walking", "Biking"]
})
foodie_plan
# Out:
#    Day      Time                                  Location Name  \
# 0    1  10:00 AM                   Food Truck 1 -> ClusterTruck
# 1    1  12:30 PM      Food Truck 2 -> big Jerry Indy food truck
# 2    1  11:00 AM              Food Truck 3 -> FELIX TACOS TRUCK
# 3    2  10:30 AM  Food Truck 4 -> The Latin Flavor - Food Truck
# 4    2   1:30 PM    Food Truck 5 -> ClusterTruck - Broad Ripple
#
#                                              Address Transportation Type
# 0  Address 1 -> 729 N Pennsylvania St, Indianapol...             Walking
# 1  Address 2 -> 8522 Madison Ave, Indianapolis, I...              Biking
# 2  Address 3 -> 3145 W Washington St, Indianapoli...             Walking
# 3  Address 4 -> 9130 E 38th St, Indianapolis, IN ...             Walking
# 4  Address 5 -> 2101 E 62nd St, Indianapolis, IN ...              Biking

# %% [markdown]
# ## Future Recommendations
#
# To further improve the foodie experience, we recommend:
#
# - Collaboration with local food truck owners for exclusive Xtern offers.
# - Developing a mobile app for easy access to food truck information and navigation.
# - Exploring additional data sources to enrich our food truck dataset.
#
# ## Conclusion
#
# This data exploration and foodie planning endeavor will significantly enhance the Xtern program's experience. It provides Xterns with a diverse culinary adventure across Indianapolis and the opportunity to explore the vibrant food truck scene.
#
# Let the foodie adventures begim
